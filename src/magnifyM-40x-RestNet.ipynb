# %% [markdown]
# # DenseNet Model 40x
#
# this file will use folder "dataset_used" that generate from "BreakHisModel-1.ipynb"
# and this will be used transfer learning / pre trained model RestNet

# %%
import os
import time
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.applications import ResNet50V2
from keras.layers import Input, Dense, Dropout, Flatten
from keras.callbacks import EarlyStopping
from tensorboard.plugins.hparams import api as hp

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
# Clear any logs from previous runs
# rm -rf ./logs/

# %%
# Checking their lengths
# train 
len_train_benign = len(os.listdir("../data_magnify/40x/Cancer_train/benign/"))
len_train_malignant = len(os.listdir("../data_magnify/40x/Cancer_train/malignant/"))
# test 
len_test_benign = len(os.listdir("../data_magnify/40x/Cancer_test/benign/"))
len_test_malignant = len(os.listdir("../data_magnify/40x/Cancer_test/malignant/"))
# val 
len_validation_benign = len(os.listdir("../data_magnify/40x/Cancer_validation/benign/"))
len_validation_malignant = len(os.listdir("../data_magnify/40x/Cancer_validation/malignant/"))

print("Training Data:")
print(" ")
print("Benign   :", len_train_benign)
print("Malignant:", len_train_malignant)
print(" ")
print("Validation Data")
print(" ")
print("Benign size    :",len_validation_benign)
print("Malignant size :",len_validation_malignant)
print(" ")
print("Testing Data:")
print(" ")
print("Benign size    :",len_test_benign)
print("Malignant size :",len_test_malignant)
# Out:
# Training Data:
#
# Benign   : 1108
# Malignant: 1108
#
# Validation Data
#
# Benign size    : 34
# Malignant size : 51
#
# Testing Data:
#
# Benign size    : 89
# Malignant size : 211

# %% [markdown]
# # Image Data Generator
# - Reference: https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator
# - Generates batches of tensor image data with real-time data augmentation.
# - Thus CNN sees new set of images with different variation at each epoch.
# - One of the useful methods to prevent the model from Overfitting.

# %%
# Defining Image Data Generator
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    horizontal_flip=True,
    vertical_flip=True,
    )

# %%
# Setting up the images for image data generator
train_generator = datagen.flow_from_directory(
  "../data_magnify/40x/Cancer_train/",
  target_size=(128, 128),
  class_mode="categorical",
  batch_size = 32,
  )

val_generator = datagen.flow_from_directory(
  "../data_magnify/40x/Cancer_validation/", 
  target_size=(128, 128), 
  class_mode="categorical",
  batch_size=32, 
  )

  # Loading the test data using Image Data Generator
test_generator = datagen.flow_from_directory(
  "../data_magnify/40x/Cancer_test/", 
  target_size=(128,128), 
  class_mode="categorical", 
  batch_size=1, 
  shuffle=False
  )
# Out:
# Found 2216 images belonging to 2 classes.
# Found 85 images belonging to 2 classes.
# Found 300 images belonging to 2 classes.

# %% [markdown]
# # RestNet Layer config
#
# ```fine_tune_at = 5 ```
# for RestNet 40x model
# ```fine_tune_at = 50 ```
# for RestNet all magnify model

# %%
#Defining the base model -> Fine Tune
RestNet50v2_layer = ResNet50V2(
  include_top=False,
  input_shape=(128, 128, 3)
)

# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(RestNet50v2_layer.layers))

# Fine-tune from this layer onwards
fine_tune_at = 50

# Freeze all the layers before the `fine_tune_at` layer
for layer in RestNet50v2_layer.layers[:fine_tune_at]:
  layer.trainable = False
# Out:
# Number of layers in the base model:  190

# %%
RestNet50v2_layer.summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 134, 134, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 64, 64, 64)   9472        ['conv1_pad[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 66, 66, 64)   0           ['conv1_conv[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 32, 32, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 32, 32, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 32, 32, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 32, 32, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 32, 32, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 34, 34, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 32, 32, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 32, 32, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 32, 32, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 32, 32, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 32, 32, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 32, 32, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 32, 32, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 32, 32, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 32, 32, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 34, 34, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 32, 32, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 32, 32, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 32, 32, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 32, 32, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 32, 32, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 32, 32, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 32, 32, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 32, 32, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 34, 34, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 16, 16, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 16, 16, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 16, 16, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 16, 16, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 16, 16, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 16, 16, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 16, 16, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 16, 16, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 16, 16, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 18, 18, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 16, 16, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 16, 16, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 16, 16, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 16, 16, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 16, 16, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 16, 16, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 16, 16, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 18, 18, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 16, 16, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 16, 16, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 16, 16, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 16, 16, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 16, 16, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 16, 16, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 18, 18, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 16, 16, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 16, 16, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 16, 16, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 16, 16, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 16, 16, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 16, 16, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 18, 18, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 8, 8, 128)    147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 8, 8, 128)   0           ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 512)   0           ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 8, 8, 512)    66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 8, 8, 512)    0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 8, 8, 512)   2048        ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 8, 8, 512)   0           ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 8, 8, 256)    131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 10, 10, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 8, 8, 256)    589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 8, 8, 1024)   525312      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 8, 8, 1024)   263168      ['conv4_block1_2_relu[0][0]']
#
#  conv4_block1_out (Add)         (None, 8, 8, 1024)   0           ['conv4_block1_0_conv[0][0]',
#                                                                   'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 8, 8, 1024)  4096        ['conv4_block1_out[0][0]']
#  ormalization)
#
#  conv4_block2_preact_relu (Acti  (None, 8, 8, 1024)  0           ['conv4_block2_preact_bn[0][0]']
#  vation)
#
#  conv4_block2_1_conv (Conv2D)   (None, 8, 8, 256)    262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 10, 10, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 8, 8, 256)    589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 8, 8, 1024)   263168      ['conv4_block2_2_relu[0][0]']
#
#  conv4_block2_out (Add)         (None, 8, 8, 1024)   0           ['conv4_block1_out[0][0]',
#                                                                   'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 8, 8, 1024)  4096        ['conv4_block2_out[0][0]']
#  ormalization)
#
#  conv4_block3_preact_relu (Acti  (None, 8, 8, 1024)  0           ['conv4_block3_preact_bn[0][0]']
#  vation)
#
#  conv4_block3_1_conv (Conv2D)   (None, 8, 8, 256)    262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 10, 10, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 8, 8, 256)    589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 8, 8, 1024)   263168      ['conv4_block3_2_relu[0][0]']
#
#  conv4_block3_out (Add)         (None, 8, 8, 1024)   0           ['conv4_block2_out[0][0]',
#                                                                   'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 8, 8, 1024)  4096        ['conv4_block3_out[0][0]']
#  ormalization)
#
#  conv4_block4_preact_relu (Acti  (None, 8, 8, 1024)  0           ['conv4_block4_preact_bn[0][0]']
#  vation)
#
#  conv4_block4_1_conv (Conv2D)   (None, 8, 8, 256)    262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 10, 10, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 8, 8, 256)    589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 8, 8, 1024)   263168      ['conv4_block4_2_relu[0][0]']
#
#  conv4_block4_out (Add)         (None, 8, 8, 1024)   0           ['conv4_block3_out[0][0]',
#                                                                   'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 8, 8, 1024)  4096        ['conv4_block4_out[0][0]']
#  ormalization)
#
#  conv4_block5_preact_relu (Acti  (None, 8, 8, 1024)  0           ['conv4_block5_preact_bn[0][0]']
#  vation)
#
#  conv4_block5_1_conv (Conv2D)   (None, 8, 8, 256)    262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 10, 10, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 8, 8, 256)    589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 8, 8, 1024)   263168      ['conv4_block5_2_relu[0][0]']
#
#  conv4_block5_out (Add)         (None, 8, 8, 1024)   0           ['conv4_block4_out[0][0]',
#                                                                   'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 8, 8, 1024)  4096        ['conv4_block5_out[0][0]']
#  ormalization)
#
#  conv4_block6_preact_relu (Acti  (None, 8, 8, 1024)  0           ['conv4_block6_preact_bn[0][0]']
#  vation)
#
#  conv4_block6_1_conv (Conv2D)   (None, 8, 8, 256)    262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 10, 10, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 4, 4, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 4, 4, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 4, 4, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 4, 4, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 4, 4, 1024)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 4, 4, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 4, 4, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 4, 4, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 6, 6, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 4, 4, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 4, 4, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 4, 4, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 4, 4, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 4, 4, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 4, 4, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 6, 6, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 4, 4, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 4, 4, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 4, 4, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 4, 4, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 4, 4, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 6, 6, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 4, 4, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 4, 4, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 4, 4, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 4, 4, 2048)   0           ['post_bn[0][0]']
#
# ==================================================================================================
# Total params: 23,564,800
# Trainable params: 22,981,120
# Non-trainable params: 583,680
# __________________________________________________________________________________________________

# %% [markdown]
# # LR optimizer
# - tf.keras.optimizers.schedules.InverseTimeDecay

# %%
N_TRAIN = int(len_train_benign) * 2
BATCH_SIZE = 32
STEPS_PER_EPOCH = N_TRAIN//BATCH_SIZE

# %%
# Setting the learning rate to reduce gradually over the training period
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
  initial_learning_rate=0.001,
  decay_steps=STEPS_PER_EPOCH*5,
  decay_rate=1,
  staircase=False)

def get_optimizer():
  return tf.keras.optimizers.Adam(lr_schedule)

# %%
step = np.linspace(0,2216)
lr = lr_schedule(step)
plt.figure(figsize = (8,6))
plt.plot(step/STEPS_PER_EPOCH, lr)
plt.ylim([0,max(plt.ylim())])
plt.xlabel('Epoch')
_ = plt.ylabel('Learning Rate')

# %% [markdown]
# # HyperParameter Tuning
# - epoch[0, 0,2, 0,4]

# %%
HP_DROPOUT = hp.HParam('dropout', hp.Discrete([0.0, 0.2, 0.4]))

METRIC_ACCURACY = 'accuracy'

with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
  hp.hparams_config(
    hparams=[HP_DROPOUT],
    metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')],
  )

early_stop = EarlyStopping(monitor='val_loss',patience=5)

# %%
def train_test_model(hparams):
  model = tf.keras.models.Sequential([
    # RestNet Layer
    RestNet50v2_layer,
    
    # Flattening the layers
    Flatten(),

    # Adding the dense layer
    Dropout(hparams[HP_DROPOUT]),
    Dense(256, activation='relu'),
    
    Dropout(hparams[HP_DROPOUT]),
    Dense(128, activation='relu'),
    Dense(2, activation='softmax'),
  ])
  model.compile(
    loss='categorical_crossentropy', 
    optimizer = get_optimizer(), 
    metrics = ['accuracy']
  )

  model.fit(
    train_generator, 
    validation_data=val_generator, 
    epochs=15,
    callbacks=[early_stop],
    verbose = 1
  ) # Run with 1 epoch to speed things up for demo purposes
  _, accuracy = model.evaluate(test_generator)
  return accuracy

# %%
def run(run_dir, hparams):
  with tf.summary.create_file_writer(run_dir).as_default():
    hp.hparams(hparams)  # record the values used in this trial
    accuracy = train_test_model(hparams)
    tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)

# %%
start_time_HP = time.time()

session_num = 0
for dropout_rate in HP_DROPOUT.domain.values:
  hparams = {
    HP_DROPOUT: dropout_rate,
  }
  run_name = "run-%d" % session_num
  print('--- Starting trial: %s' % run_name)
  print({h.name: hparams[h] for h in hparams})
  run('logs/hparam_tuning/' + run_name, hparams)
  session_num += 1
# Out:
# --- Starting trial: run-0
# {'dropout': 0.0}
# Epoch 1/15
# 70/70 [==============================] - 86s 903ms/step - loss: 0.6090 - accuracy: 0.7590 - val_loss: 92.4981 - val_accuracy: 0.4118
# Epoch 2/15
# 70/70 [==============================] - 56s 788ms/step - loss: 0.3457 - accuracy: 0.8542 - val_loss: 15.2799 - val_accuracy: 0.5529
# Epoch 3/15
# 70/70 [==============================] - 57s 799ms/step - loss: 0.3062 - accuracy: 0.8962 - val_loss: 0.3407 - val_accuracy: 0.8706
# Epoch 4/15
# 70/70 [==============================] - 63s 889ms/step - loss: 0.2086 - accuracy: 0.9273 - val_loss: 55.2038 - val_accuracy: 0.6118
# Epoch 5/15
# 70/70 [==============================] - 57s 809ms/step - loss: 0.2851 - accuracy: 0.8912 - val_loss: 310.9136 - val_accuracy: 0.4588
# Epoch 6/15
# 70/70 [==============================] - 58s 823ms/step - loss: 0.2118 - accuracy: 0.9138 - val_loss: 0.3317 - val_accuracy: 0.9059
# Epoch 7/15
# 70/70 [==============================] - 58s 816ms/step - loss: 0.2497 - accuracy: 0.9025 - val_loss: 0.3701 - val_accuracy: 0.8471
# Epoch 8/15
# 70/70 [==============================] - 61s 857ms/step - loss: 0.2221 - accuracy: 0.9174 - val_loss: 0.4684 - val_accuracy: 0.8824
# Epoch 9/15
# 70/70 [==============================] - 57s 813ms/step - loss: 0.2078 - accuracy: 0.9382 - val_loss: 0.9345 - val_accuracy: 0.7765
# Epoch 10/15
# 70/70 [==============================] - 61s 859ms/step - loss: 0.1237 - accuracy: 0.9540 - val_loss: 0.8183 - val_accuracy: 0.8118
# Epoch 11/15
# 70/70 [==============================] - 61s 871ms/step - loss: 0.1068 - accuracy: 0.9616 - val_loss: 0.1924 - val_accuracy: 0.9176
# Epoch 12/15
# 70/70 [==============================] - 61s 867ms/step - loss: 0.0927 - accuracy: 0.9671 - val_loss: 0.3471 - val_accuracy: 0.8706
# Epoch 13/15
# 70/70 [==============================] - 61s 864ms/step - loss: 0.0723 - accuracy: 0.9707 - val_loss: 0.2618 - val_accuracy: 0.9529
# Epoch 14/15
# 70/70 [==============================] - 57s 807ms/step - loss: 0.0816 - accuracy: 0.9716 - val_loss: 0.1623 - val_accuracy: 0.9294
# Epoch 15/15
# 70/70 [==============================] - 58s 825ms/step - loss: 0.1645 - accuracy: 0.9472 - val_loss: 0.3163 - val_accuracy: 0.8824
# 10/10 [==============================] - 13s 1s/step - loss: 0.4046 - accuracy: 0.8900
# --- Starting trial: run-1
# {'dropout': 0.2}
# Epoch 1/15
# 70/70 [==============================] - 70s 828ms/step - loss: 0.4686 - accuracy: 0.8421 - val_loss: 999305.4375 - val_accuracy: 0.4000
# Epoch 2/15
# 70/70 [==============================] - 59s 838ms/step - loss: 0.6402 - accuracy: 0.7816 - val_loss: 29432.7598 - val_accuracy: 0.4000
# Epoch 3/15
# 70/70 [==============================] - 61s 863ms/step - loss: 0.5714 - accuracy: 0.8326 - val_loss: 1426.0676 - val_accuracy: 0.5412
# Epoch 4/15
# 70/70 [==============================] - 58s 823ms/step - loss: 0.5935 - accuracy: 0.8186 - val_loss: 1.0384 - val_accuracy: 0.6824
# Epoch 5/15
# 70/70 [==============================] - 57s 809ms/step - loss: 0.9229 - accuracy: 0.8105 - val_loss: 1816.1599 - val_accuracy: 0.4000
# Epoch 6/15
# 70/70 [==============================] - 58s 820ms/step - loss: 0.4330 - accuracy: 0.8655 - val_loss: 492.7150 - val_accuracy: 0.5059
# Epoch 7/15
# 70/70 [==============================] - 61s 864ms/step - loss: 0.3466 - accuracy: 0.8583 - val_loss: 0.4543 - val_accuracy: 0.8588
# Epoch 8/15
# 70/70 [==============================] - 59s 833ms/step - loss: 0.2470 - accuracy: 0.8980 - val_loss: 0.4249 - val_accuracy: 0.8471
# Epoch 9/15
# 70/70 [==============================] - 64s 905ms/step - loss: 0.3073 - accuracy: 0.8831 - val_loss: 0.5449 - val_accuracy: 0.7882
# Epoch 10/15
# 70/70 [==============================] - 62s 879ms/step - loss: 0.2419 - accuracy: 0.8967 - val_loss: 0.1846 - val_accuracy: 0.9176
# Epoch 11/15
# 70/70 [==============================] - 60s 843ms/step - loss: 0.1767 - accuracy: 0.9328 - val_loss: 0.1868 - val_accuracy: 0.9294
# Epoch 12/15
# 70/70 [==============================] - 63s 886ms/step - loss: 0.1656 - accuracy: 0.9355 - val_loss: 0.2261 - val_accuracy: 0.9176
# Epoch 13/15
# 70/70 [==============================] - 58s 814ms/step - loss: 0.1400 - accuracy: 0.9504 - val_loss: 0.3031 - val_accuracy: 0.9059
# Epoch 14/15
# 70/70 [==============================] - 63s 885ms/step - loss: 0.1318 - accuracy: 0.9477 - val_loss: 0.2890 - val_accuracy: 0.9294
# Epoch 15/15
# 70/70 [==============================] - 57s 809ms/step - loss: 0.1332 - accuracy: 0.9508 - val_loss: 0.3195 - val_accuracy: 0.9176
# 10/10 [==============================] - 7s 683ms/step - loss: 0.3233 - accuracy: 0.8867
# --- Starting trial: run-2
# {'dropout': 0.4}
# Epoch 1/15
# 70/70 [==============================] - 69s 850ms/step - loss: 0.3147 - accuracy: 0.8818 - val_loss: 0.9464 - val_accuracy: 0.8353
# Epoch 2/15
# 70/70 [==============================] - 56s 797ms/step - loss: 0.4744 - accuracy: 0.8854 - val_loss: 43.8294 - val_accuracy: 0.8471
# Epoch 3/15
# 70/70 [==============================] - 59s 833ms/step - loss: 1.5493 - accuracy: 0.8177 - val_loss: 2546.8745 - val_accuracy: 0.6118
# Epoch 4/15
# 70/70 [==============================] - 61s 866ms/step - loss: 0.7348 - accuracy: 0.8759 - val_loss: 0.7172 - val_accuracy: 0.8118
# Epoch 5/15
# 70/70 [==============================] - 58s 820ms/step - loss: 0.3016 - accuracy: 0.8768 - val_loss: 0.2516 - val_accuracy: 0.9059
# Epoch 6/15
# 70/70 [==============================] - 62s 876ms/step - loss: 0.2450 - accuracy: 0.9088 - val_loss: 0.2487 - val_accuracy: 0.9059
# Epoch 7/15
# 70/70 [==============================] - 58s 820ms/step - loss: 0.2070 - accuracy: 0.9215 - val_loss: 0.2156 - val_accuracy: 0.8824
# Epoch 8/15
# 70/70 [==============================] - 62s 876ms/step - loss: 0.1736 - accuracy: 0.9346 - val_loss: 0.2043 - val_accuracy: 0.9294
# Epoch 9/15
# 70/70 [==============================] - 62s 886ms/step - loss: 0.1659 - accuracy: 0.9319 - val_loss: 0.1450 - val_accuracy: 0.9647
# Epoch 10/15
# 70/70 [==============================] - 61s 866ms/step - loss: 0.1471 - accuracy: 0.9486 - val_loss: 0.1626 - val_accuracy: 0.9176
# Epoch 11/15
# 70/70 [==============================] - 58s 820ms/step - loss: 0.1558 - accuracy: 0.9418 - val_loss: 0.3404 - val_accuracy: 0.8706
# Epoch 12/15
# 70/70 [==============================] - 62s 873ms/step - loss: 0.1514 - accuracy: 0.9463 - val_loss: 0.1469 - val_accuracy: 0.9412
# Epoch 13/15
# 70/70 [==============================] - 58s 825ms/step - loss: 0.1281 - accuracy: 0.9558 - val_loss: 0.1916 - val_accuracy: 0.9412
# Epoch 14/15
# 70/70 [==============================] - 61s 868ms/step - loss: 0.0964 - accuracy: 0.9666 - val_loss: 0.2011 - val_accuracy: 0.9176
# 10/10 [==============================] - 7s 646ms/step - loss: 0.2055 - accuracy: 0.9133

# %%
end_time_HP = time.time()

# %%
Total_time_second= end_time_HP - start_time_HP
convert_minute = (Total_time_second) // 60
modulo_second = (Total_time_second) % 60
print("total time run HyperParameter Tune : {} Minutes, {} Seconds".format(convert_minute, modulo_second) )
# Out:
# total time run HyperParameter Tune : 45.0 Minutes, 6.292205333709717 Seconds

# %%
# %tensorboard --logdir logs/hparam_tuning
# Out:
# Reusing TensorBoard on port 6006 (pid 15412), started 2 days, 13:28:16 ago. (Use '!kill 15412' to kill it.)
#       <iframe id="tensorboard-frame-ececf99eafb597d2" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-ececf99eafb597d2");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# # model CNN Pretrained model
# - with DenseNet

# %%
cancer_model = Sequential([
  # RestNet Layer
  RestNet50v2_layer,
  
  # Flattening the layers
  Flatten(),
  Dropout(0.4),

  # Adding the dense layer
  Dense(256, activation='relu'),
  Dropout(0.4),
  
  Dense(128, activation='relu'),
  Dense(2, activation='softmax'),
])

# cancer_model.layers[0].trainable = False
cancer_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 4, 4, 2048)        23564800
#
#  flatten_2 (Flatten)         (None, 32768)             0
#
#  dropout_4 (Dropout)         (None, 32768)             0
#
#  dense_6 (Dense)             (None, 256)               8388864
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  dense_8 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 31,986,818
# Trainable params: 31,403,138
# Non-trainable params: 583,680
# _________________________________________________________________

# %%
# Compiling the model
cancer_model.compile(
  loss='categorical_crossentropy', 
  optimizer = get_optimizer(), 
  metrics = ['accuracy']
)

early_stop = EarlyStopping(monitor='val_loss',patience=10)

# %%
# Model is fitted using train and validation generator for 200 epochs
import time

start_time = time.time()

history = cancer_model.fit(
  train_generator, 
  validation_data=val_generator, 
  epochs=200 ,
  callbacks=[early_stop],
  verbose = 1
  )
# Out:
# Epoch 1/200
# 70/70 [==============================] - 82s 1s/step - loss: 0.7152 - accuracy: 0.6900 - val_loss: 27.4645 - val_accuracy: 0.6000
# Epoch 2/200
# 70/70 [==============================] - 65s 918ms/step - loss: 0.4527 - accuracy: 0.7956 - val_loss: 7.8148 - val_accuracy: 0.6235
# Epoch 3/200
# 70/70 [==============================] - 67s 952ms/step - loss: 0.3333 - accuracy: 0.8678 - val_loss: 1.0473 - val_accuracy: 0.8353
# Epoch 4/200
# 70/70 [==============================] - 67s 953ms/step - loss: 0.2827 - accuracy: 0.8827 - val_loss: 0.5336 - val_accuracy: 0.7059
# Epoch 5/200
# 70/70 [==============================] - 68s 966ms/step - loss: 0.2777 - accuracy: 0.8881 - val_loss: 0.6103 - val_accuracy: 0.8471
# Epoch 6/200
# 70/70 [==============================] - 69s 971ms/step - loss: 0.1816 - accuracy: 0.9292 - val_loss: 0.2746 - val_accuracy: 0.8941
# Epoch 7/200
# 70/70 [==============================] - 71s 1s/step - loss: 0.1635 - accuracy: 0.9296 - val_loss: 0.4979 - val_accuracy: 0.9294
# Epoch 8/200
# 70/70 [==============================] - 71s 1s/step - loss: 0.1483 - accuracy: 0.9427 - val_loss: 0.2310 - val_accuracy: 0.9412
# Epoch 9/200
# 70/70 [==============================] - 71s 1s/step - loss: 0.1649 - accuracy: 0.9409 - val_loss: 0.5437 - val_accuracy: 0.8588
# Epoch 10/200
# 70/70 [==============================] - 71s 1s/step - loss: 0.1238 - accuracy: 0.9571 - val_loss: 0.2722 - val_accuracy: 0.8941
# Epoch 11/200
# 70/70 [==============================] - 70s 992ms/step - loss: 0.1171 - accuracy: 0.9562 - val_loss: 0.2222 - val_accuracy: 0.9412
# Epoch 12/200
# 70/70 [==============================] - 70s 1000ms/step - loss: 0.1506 - accuracy: 0.9486 - val_loss: 0.9602 - val_accuracy: 0.7412
# Epoch 13/200
# 70/70 [==============================] - 71s 1s/step - loss: 0.1757 - accuracy: 0.9427 - val_loss: 0.4216 - val_accuracy: 0.8824
# Epoch 14/200
# 70/70 [==============================] - 72s 1s/step - loss: 0.1522 - accuracy: 0.9486 - val_loss: 0.4381 - val_accuracy: 0.8706
# Epoch 15/200
# 70/70 [==============================] - 72s 1s/step - loss: 0.1301 - accuracy: 0.9549 - val_loss: 0.1522 - val_accuracy: 0.9412
# Epoch 16/200
# 70/70 [==============================] - 71s 999ms/step - loss: 0.0909 - accuracy: 0.9675 - val_loss: 0.1103 - val_accuracy: 0.9412
# Epoch 17/200
# 70/70 [==============================] - 72s 1s/step - loss: 0.1085 - accuracy: 0.9612 - val_loss: 0.1414 - val_accuracy: 0.9412
# Epoch 18/200
# 70/70 [==============================] - 73s 1s/step - loss: 0.0943 - accuracy: 0.9662 - val_loss: 0.1316 - val_accuracy: 0.9412
# Epoch 19/200
# 70/70 [==============================] - 67s 954ms/step - loss: 0.0702 - accuracy: 0.9779 - val_loss: 0.2657 - val_accuracy: 0.9412
# Epoch 20/200
# 70/70 [==============================] - 72s 1s/step - loss: 0.1391 - accuracy: 0.9612 - val_loss: 5.0422 - val_accuracy: 0.8824
# Epoch 21/200
# 70/70 [==============================] - 72s 1s/step - loss: 0.0756 - accuracy: 0.9738 - val_loss: 0.1002 - val_accuracy: 0.9647
# Epoch 22/200
# 70/70 [==============================] - 72s 1s/step - loss: 0.0626 - accuracy: 0.9788 - val_loss: 0.6419 - val_accuracy: 0.8941
# Epoch 23/200
# 70/70 [==============================] - 71s 1s/step - loss: 0.0715 - accuracy: 0.9761 - val_loss: 0.2932 - val_accuracy: 0.8824
# Epoch 24/200
# 70/70 [==============================] - 71s 1s/step - loss: 0.1011 - accuracy: 0.9644 - val_loss: 0.2244 - val_accuracy: 0.9294
# Epoch 25/200
# 70/70 [==============================] - 75s 1s/step - loss: 0.0944 - accuracy: 0.9702 - val_loss: 0.1432 - val_accuracy: 0.9529
# Epoch 26/200
# 70/70 [==============================] - 70s 1s/step - loss: 0.0498 - accuracy: 0.9819 - val_loss: 0.2476 - val_accuracy: 0.9294
# Epoch 27/200
# 70/70 [==============================] - 72s 1s/step - loss: 0.0667 - accuracy: 0.9806 - val_loss: 0.1022 - val_accuracy: 0.9882
# Epoch 28/200
# 70/70 [==============================] - 74s 1s/step - loss: 0.0298 - accuracy: 0.9905 - val_loss: 0.1300 - val_accuracy: 0.9647
# Epoch 29/200
# 70/70 [==============================] - 71s 1s/step - loss: 0.0376 - accuracy: 0.9896 - val_loss: 0.0883 - val_accuracy: 0.9529
# Epoch 30/200
# 70/70 [==============================] - 75s 1s/step - loss: 0.0565 - accuracy: 0.9829 - val_loss: 0.0928 - val_accuracy: 0.9647
# Epoch 31/200
# 70/70 [==============================] - 67s 951ms/step - loss: 0.0563 - accuracy: 0.9797 - val_loss: 0.0852 - val_accuracy: 0.9647
# Epoch 32/200
# 70/70 [==============================] - 71s 1s/step - loss: 0.0322 - accuracy: 0.9901 - val_loss: 0.1009 - val_accuracy: 0.9647
# Epoch 33/200
# 70/70 [==============================] - 73s 1s/step - loss: 0.0307 - accuracy: 0.9883 - val_loss: 0.3764 - val_accuracy: 0.9294
# Epoch 34/200
# 70/70 [==============================] - 72s 1s/step - loss: 0.0395 - accuracy: 0.9860 - val_loss: 0.1825 - val_accuracy: 0.9647
# Epoch 35/200
# 70/70 [==============================] - 74s 1s/step - loss: 0.0370 - accuracy: 0.9910 - val_loss: 0.2897 - val_accuracy: 0.9412
# Epoch 36/200
# 70/70 [==============================] - 71s 1s/step - loss: 0.0253 - accuracy: 0.9941 - val_loss: 0.1303 - val_accuracy: 0.9765
# Epoch 37/200
# 70/70 [==============================] - 73s 1s/step - loss: 0.0302 - accuracy: 0.9901 - val_loss: 0.0877 - val_accuracy: 0.9647
# Epoch 38/200
# 70/70 [==============================] - 71s 1s/step - loss: 0.0454 - accuracy: 0.9883 - val_loss: 0.2146 - val_accuracy: 0.9529
# Epoch 39/200
# 70/70 [==============================] - 74s 1s/step - loss: 0.0171 - accuracy: 0.9964 - val_loss: 0.0545 - val_accuracy: 0.9647
# Epoch 40/200
# 70/70 [==============================] - 72s 1s/step - loss: 0.0225 - accuracy: 0.9928 - val_loss: 0.0550 - val_accuracy: 0.9647
# Epoch 41/200
# 70/70 [==============================] - 73s 1s/step - loss: 0.0412 - accuracy: 0.9860 - val_loss: 0.1684 - val_accuracy: 0.9882
# Epoch 42/200
# 70/70 [==============================] - 73s 1s/step - loss: 0.0131 - accuracy: 0.9973 - val_loss: 0.1210 - val_accuracy: 0.9765
# Epoch 43/200
# 70/70 [==============================] - 74s 1s/step - loss: 0.0133 - accuracy: 0.9973 - val_loss: 0.2608 - val_accuracy: 0.9647
# Epoch 44/200
# 70/70 [==============================] - 74s 1s/step - loss: 0.0312 - accuracy: 0.9883 - val_loss: 0.3357 - val_accuracy: 0.9412
# Epoch 45/200
# 70/70 [==============================] - 73s 1s/step - loss: 0.0129 - accuracy: 0.9964 - val_loss: 0.2159 - val_accuracy: 0.9765
# Epoch 46/200
# 70/70 [==============================] - 72s 1s/step - loss: 0.0231 - accuracy: 0.9919 - val_loss: 0.1817 - val_accuracy: 0.9647
# Epoch 47/200
# 70/70 [==============================] - 74s 1s/step - loss: 0.0306 - accuracy: 0.9896 - val_loss: 0.0965 - val_accuracy: 0.9647
# Epoch 48/200
# 70/70 [==============================] - 74s 1s/step - loss: 0.0182 - accuracy: 0.9950 - val_loss: 0.0338 - val_accuracy: 0.9882
# Epoch 49/200
# 70/70 [==============================] - 74s 1s/step - loss: 0.0442 - accuracy: 0.9887 - val_loss: 0.1953 - val_accuracy: 0.9529
# Epoch 50/200
# 70/70 [==============================] - 74s 1s/step - loss: 0.0311 - accuracy: 0.9919 - val_loss: 0.0905 - val_accuracy: 0.9765
# Epoch 51/200
# 70/70 [==============================] - 73s 1s/step - loss: 0.0100 - accuracy: 0.9973 - val_loss: 0.1188 - val_accuracy: 0.9647
# Epoch 52/200
# 70/70 [==============================] - 73s 1s/step - loss: 0.0103 - accuracy: 0.9964 - val_loss: 0.0743 - val_accuracy: 0.9882
# Epoch 53/200
# 70/70 [==============================] - 72s 1s/step - loss: 0.0113 - accuracy: 0.9959 - val_loss: 0.0976 - val_accuracy: 0.9765
# Epoch 54/200
# 70/70 [==============================] - 72s 1s/step - loss: 0.0186 - accuracy: 0.9932 - val_loss: 0.1865 - val_accuracy: 0.9529
# Epoch 55/200
# 70/70 [==============================] - 75s 1s/step - loss: 0.0121 - accuracy: 0.9955 - val_loss: 0.1374 - val_accuracy: 0.9765
# Epoch 56/200
# 70/70 [==============================] - 70s 999ms/step - loss: 0.0120 - accuracy: 0.9950 - val_loss: 0.0346 - val_accuracy: 0.9882
# Epoch 57/200
# 70/70 [==============================] - 71s 1s/step - loss: 0.0092 - accuracy: 0.9973 - val_loss: 0.3676 - val_accuracy: 0.9176
# Epoch 58/200
# 70/70 [==============================] - 74s 1s/step - loss: 0.0250 - accuracy: 0.9928 - val_loss: 0.2601 - val_accuracy: 0.9412

# %%
end_time = time.time()
print("The time of execution of above program is :",(end_time-start_time) * 10**3, "ms")
# Out:
# The time of execution of above program is : 409386.27648353577 ms

# %%
Total_time_second= end_time-start_time
convert_minute = (Total_time_second) // 60
modulo_second = (Total_time_second) % 60
print("total time run : {} Minutes, {} Seconds".format(convert_minute, modulo_second) )
# Out:
# total time run : 6.0 Minutes, 49.38627648353577 Seconds

# %%
# Plotting the model results

# Getting the accuracy
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Getting the losses
loss = history.history['loss']
val_loss = history.history['val_loss']

# No of epochs it trained
epochs_range = history.epoch

# Plotting Training and Validation accuracy
plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

#Plotting Training and Validation Loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
pred = cancer_model.evaluate(test_generator)
# Out:
# 300/300 [==============================] - 17s 43ms/step - loss: 0.1289 - accuracy: 0.9600

# %%
# os.mkdir("../src/output/restnet")

# %%
cancer_model.save(filepath="../src/output/restnet/restnet_40x_hp.h5")

# %% [markdown]
# # Load model and model evaluation

# %%
cancer_model.load_weights(filepath="../src/output/restnet/restnet_40x_hp.h5")

# %% [markdown]
# ## test load model

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns

pred = cancer_model.predict(test_generator)
y_pred = np.argmax(pred, axis=1)

print("==== Confusion Mtrix ====")
print(confusion_matrix(test_generator.classes, y_pred))
# Out:
# 300/300 [==============================] - 12s 41ms/step
# ==== Confusion Mtrix ====
# [[ 80   9]
#  [  4 207]]

# %%
confusion_mtx = tf.math.confusion_matrix(test_generator.classes, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=["Benign", "Malignant"],
            yticklabels=["Benign", "Malignant"],
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %%
print(classification_report(test_generator.classes, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.92        89
#            1       0.96      0.98      0.97       211
#
#     accuracy                           0.96       300
#    macro avg       0.96      0.94      0.95       300
# weighted avg       0.96      0.96      0.96       300

# %% [markdown]
# # Load model and model evaluation with model all magnify

# %%
cancer_model.load_weights(filepath="../src/output/restnet/restnet50v2_model__HP_fineTune_FIX-v2.h5")

# %% [markdown]
# ## test load model

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns

pred = cancer_model.predict(test_generator)
y_pred = np.argmax(pred, axis=1)

print("==== Confusion Mtrix ====")
print(confusion_matrix(test_generator.classes, y_pred))
# Out:
# 300/300 [==============================] - 13s 41ms/step
# ==== Confusion Mtrix ====
# [[ 87   2]
#  [ 15 196]]

# %%
confusion_mtx = tf.math.confusion_matrix(test_generator.classes, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=["Benign", "Malignant"],
            yticklabels=["Benign", "Malignant"],
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %%
print(classification_report(test_generator.classes, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.92        89
#            1       0.96      0.98      0.97       211
#
#     accuracy                           0.96       300
#    macro avg       0.96      0.94      0.95       300
# weighted avg       0.96      0.96      0.96       300
